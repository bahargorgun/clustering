# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

data=pd.read_csv('wave.csv')

df= data.iloc[:,[2]]
X = data.iloc[:,[0]]
y = data.iloc[:,[1]]


kmeans = KMeans(n_clusters=4).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)
list(df.columns)

plt.scatter(X,y,c= kmeans.labels_.astype(int), s=15, alpha=1)
# Out:
# [[-9.76996262e-15]
#  [ 2.00000000e+00]
#  [ 1.00000000e+00]
#  [ 3.00000000e+00]]
